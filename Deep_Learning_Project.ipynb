# %% [markdown]
# DOMAIN: Electronics and Telecommunication
#
# DATA DESCRIPTION: The data set contains information on various signal tests performed:
# 1. Parameters: Various measurable signal parameters.
# 2. Signal_Quality: Final signal strength or quality

# %% [markdown]
# PROJECT OBJECTIVE: To build a classifier which can use the given parameters to determine the signal strength or quality

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Deep Learing Dataset/Signal.csv')

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.head()
# Out:
#    Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 0          7.4         0.70         0.00          1.9        0.076
# 1          7.8         0.88         0.00          2.6        0.098
# 2          7.8         0.76         0.04          2.3        0.092
# 3         11.2         0.28         0.56          1.9        0.075
# 4          7.4         0.70         0.00          1.9        0.076
#
#    Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# 0         11.0         34.0       0.9978         3.51          0.56
# 1         25.0         67.0       0.9968         3.20          0.68
# 2         15.0         54.0       0.9970         3.26          0.65
# 3         17.0         60.0       0.9980         3.16          0.58
# 4         11.0         34.0       0.9978         3.51          0.56
#
#    Parameter 11  Signal_Strength
# 0           9.4                5
# 1           9.8                5
# 2           9.8                5
# 3           9.8                6
# 4           9.4                5

# %%
df.isna().sum()/len(df)
# Out:
# Parameter 1        0.0
# Parameter 2        0.0
# Parameter 3        0.0
# Parameter 4        0.0
# Parameter 5        0.0
# Parameter 6        0.0
# Parameter 7        0.0
# Parameter 8        0.0
# Parameter 9        0.0
# Parameter 10       0.0
# Parameter 11       0.0
# Signal_Strength    0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(keep ='first',inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.pairplot(df,hue  = 'Signal_Strength',palette='Set2')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.describe().transpose()
# Out:
#                   count       mean        std      min      25%      50%  \
# Parameter 1      1359.0   8.310596   1.736990  4.60000   7.1000   7.9000
# Parameter 2      1359.0   0.529478   0.183031  0.12000   0.3900   0.5200
# Parameter 3      1359.0   0.272333   0.195537  0.00000   0.0900   0.2600
# Parameter 4      1359.0   2.523400   1.352314  0.90000   1.9000   2.2000
# Parameter 5      1359.0   0.088124   0.049377  0.01200   0.0700   0.0790
# Parameter 6      1359.0  15.893304  10.447270  1.00000   7.0000  14.0000
# Parameter 7      1359.0  46.825975  33.408946  6.00000  22.0000  38.0000
# Parameter 8      1359.0   0.996709   0.001869  0.99007   0.9956   0.9967
# Parameter 9      1359.0   3.309787   0.155036  2.74000   3.2100   3.3100
# Parameter 10     1359.0   0.658705   0.170667  0.33000   0.5500   0.6200
# Parameter 11     1359.0  10.432315   1.082065  8.40000   9.5000  10.2000
# Signal_Strength  1359.0   5.623252   0.823578  3.00000   5.0000   6.0000
#
#                       75%        max
# Parameter 1       9.20000   15.90000
# Parameter 2       0.64000    1.58000
# Parameter 3       0.43000    1.00000
# Parameter 4       2.60000   15.50000
# Parameter 5       0.09100    0.61100
# Parameter 6      21.00000   72.00000
# Parameter 7      63.00000  289.00000
# Parameter 8       0.99782    1.00369
# Parameter 9       3.40000    4.01000
# Parameter 10      0.73000    2.00000
# Parameter 11     11.10000   14.90000
# Signal_Strength   6.00000    8.00000

# %%
sns.countplot(data = df,x = 'Signal_Strength')
# Out:
# <Axes: xlabel='Signal_Strength', ylabel='count'>

# %%
df['Signal_Strength'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
X = df.drop("Signal_Strength",axis  = 1)
y = df['Signal_Strength']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (951, 11)
# (951,)
# (408, 11)
# (408,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (951, 11) (408, 11)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (951, 9)
# (408, 9)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization,Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(11, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))
NN_model.add(BatchNormalization())

NN_model.add(Dense(9,activation='relu'))

NN_model.add(Dense(9,activation='relu'))
# The Output Layer :
NN_model.add(Dense(9,activation='softmax'))  # except softmax

# Compile the network :
NN_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 11)                132
#
#  batch_normalization (Batch  (None, 11)                44
#  Normalization)
#
#  dense_1 (Dense)             (None, 9)                 108
#
#  dense_2 (Dense)             (None, 9)                 90
#
#  dense_3 (Dense)             (None, 9)                 90
#
# =================================================================
# Total params: 464 (1.81 KB)
# Trainable params: 442 (1.73 KB)
# Non-trainable params: 22 (88.00 Byte)
# _________________________________________________________________

# %%
NN_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics='accuracy')

# %%
model_train = NN_model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 4s 14ms/step - loss: 2.0416 - accuracy: 0.1283 - val_loss: 2.0704 - val_accuracy: 0.3652
# Epoch 2/100
# 30/30 [==============================] - 0s 7ms/step - loss: 1.8479 - accuracy: 0.2355 - val_loss: 1.9611 - val_accuracy: 0.4583
# Epoch 3/100
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6771 - accuracy: 0.3544 - val_loss: 1.8309 - val_accuracy: 0.5147
# Epoch 4/100
# 30/30 [==============================] - 0s 6ms/step - loss: 1.5067 - accuracy: 0.4553 - val_loss: 1.6835 - val_accuracy: 0.5343
# Epoch 5/100
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3523 - accuracy: 0.5310 - val_loss: 1.5315 - val_accuracy: 0.5319
# Epoch 6/100
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2323 - accuracy: 0.5510 - val_loss: 1.3984 - val_accuracy: 0.5098
# Epoch 7/100
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1513 - accuracy: 0.5752 - val_loss: 1.2827 - val_accuracy: 0.5515
# Epoch 8/100
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0951 - accuracy: 0.5710 - val_loss: 1.1949 - val_accuracy: 0.5686
# Epoch 9/100
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0587 - accuracy: 0.5783 - val_loss: 1.1399 - val_accuracy: 0.5760
# Epoch 10/100
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0272 - accuracy: 0.5941 - val_loss: 1.0954 - val_accuracy: 0.5858
# Epoch 11/100
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0104 - accuracy: 0.6046 - val_loss: 1.0521 - val_accuracy: 0.6054
# Epoch 12/100
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0004 - accuracy: 0.5868 - val_loss: 1.0292 - val_accuracy: 0.5858
# Epoch 13/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9934 - accuracy: 0.5910 - val_loss: 1.0054 - val_accuracy: 0.5858
# Epoch 14/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9857 - accuracy: 0.5994 - val_loss: 0.9954 - val_accuracy: 0.5809
# Epoch 15/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9728 - accuracy: 0.5941 - val_loss: 0.9775 - val_accuracy: 0.6005
# Epoch 16/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9611 - accuracy: 0.6067 - val_loss: 0.9688 - val_accuracy: 0.5907
# Epoch 17/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9564 - accuracy: 0.5994 - val_loss: 0.9589 - val_accuracy: 0.6078
# Epoch 18/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9541 - accuracy: 0.6057 - val_loss: 0.9544 - val_accuracy: 0.5980
# Epoch 19/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.9592 - accuracy: 0.5983 - val_loss: 0.9608 - val_accuracy: 0.6078
# Epoch 20/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9464 - accuracy: 0.6046 - val_loss: 0.9519 - val_accuracy: 0.5980
# Epoch 21/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9314 - accuracy: 0.6151 - val_loss: 0.9398 - val_accuracy: 0.6152
# Epoch 22/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9272 - accuracy: 0.6067 - val_loss: 0.9409 - val_accuracy: 0.6103
# Epoch 23/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9335 - accuracy: 0.6025 - val_loss: 0.9382 - val_accuracy: 0.6078
# Epoch 24/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9272 - accuracy: 0.6078 - val_loss: 0.9443 - val_accuracy: 0.6029
# Epoch 25/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9167 - accuracy: 0.6151 - val_loss: 0.9445 - val_accuracy: 0.6029
# Epoch 26/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9181 - accuracy: 0.6236 - val_loss: 0.9481 - val_accuracy: 0.6005
# Epoch 27/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9126 - accuracy: 0.6330 - val_loss: 0.9464 - val_accuracy: 0.6176
# Epoch 28/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.9217 - accuracy: 0.6151 - val_loss: 0.9406 - val_accuracy: 0.6201
# Epoch 29/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.9021 - accuracy: 0.6267 - val_loss: 0.9456 - val_accuracy: 0.6152
# Epoch 30/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.9116 - accuracy: 0.6341 - val_loss: 0.9473 - val_accuracy: 0.6201
# Epoch 31/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.9082 - accuracy: 0.6299 - val_loss: 0.9527 - val_accuracy: 0.6078
# Epoch 32/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.9017 - accuracy: 0.6341 - val_loss: 0.9555 - val_accuracy: 0.5980
# Epoch 33/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8915 - accuracy: 0.6372 - val_loss: 0.9514 - val_accuracy: 0.6054
# Epoch 34/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8860 - accuracy: 0.6215 - val_loss: 0.9574 - val_accuracy: 0.6054
# Epoch 35/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8944 - accuracy: 0.6257 - val_loss: 0.9538 - val_accuracy: 0.6054
# Epoch 36/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8890 - accuracy: 0.6446 - val_loss: 0.9559 - val_accuracy: 0.6176
# Epoch 37/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8957 - accuracy: 0.6236 - val_loss: 0.9588 - val_accuracy: 0.5956
# Epoch 38/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8878 - accuracy: 0.6309 - val_loss: 0.9612 - val_accuracy: 0.5980
# Epoch 39/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.8850 - accuracy: 0.6246 - val_loss: 0.9591 - val_accuracy: 0.5956
# Epoch 40/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8882 - accuracy: 0.6278 - val_loss: 0.9634 - val_accuracy: 0.6078
# Epoch 41/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8713 - accuracy: 0.6383 - val_loss: 0.9553 - val_accuracy: 0.5956
# Epoch 42/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8772 - accuracy: 0.6435 - val_loss: 0.9575 - val_accuracy: 0.6054
# Epoch 43/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8682 - accuracy: 0.6488 - val_loss: 0.9629 - val_accuracy: 0.6078
# Epoch 44/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8815 - accuracy: 0.6393 - val_loss: 0.9562 - val_accuracy: 0.6005
# Epoch 45/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8666 - accuracy: 0.6477 - val_loss: 0.9565 - val_accuracy: 0.6078
# Epoch 46/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8755 - accuracy: 0.6372 - val_loss: 0.9626 - val_accuracy: 0.5956
# Epoch 47/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8768 - accuracy: 0.6299 - val_loss: 0.9539 - val_accuracy: 0.5931
# Epoch 48/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8737 - accuracy: 0.6488 - val_loss: 0.9568 - val_accuracy: 0.5882
# Epoch 49/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8727 - accuracy: 0.6309 - val_loss: 0.9690 - val_accuracy: 0.5907
# Epoch 50/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8615 - accuracy: 0.6551 - val_loss: 0.9595 - val_accuracy: 0.5858
# Epoch 51/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8594 - accuracy: 0.6435 - val_loss: 0.9551 - val_accuracy: 0.5858
# Epoch 52/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8631 - accuracy: 0.6309 - val_loss: 0.9592 - val_accuracy: 0.5882
# Epoch 53/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8627 - accuracy: 0.6414 - val_loss: 0.9600 - val_accuracy: 0.5833
# Epoch 54/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8554 - accuracy: 0.6456 - val_loss: 0.9493 - val_accuracy: 0.5931
# Epoch 55/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8574 - accuracy: 0.6330 - val_loss: 0.9517 - val_accuracy: 0.5956
# Epoch 56/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8729 - accuracy: 0.6414 - val_loss: 0.9523 - val_accuracy: 0.6029
# Epoch 57/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8727 - accuracy: 0.6404 - val_loss: 0.9420 - val_accuracy: 0.5956
# Epoch 58/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8606 - accuracy: 0.6456 - val_loss: 0.9562 - val_accuracy: 0.6029
# Epoch 59/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8596 - accuracy: 0.6488 - val_loss: 0.9583 - val_accuracy: 0.5980
# Epoch 60/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8579 - accuracy: 0.6488 - val_loss: 0.9662 - val_accuracy: 0.5956
# Epoch 61/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8585 - accuracy: 0.6404 - val_loss: 0.9565 - val_accuracy: 0.5907
# Epoch 62/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8537 - accuracy: 0.6509 - val_loss: 0.9602 - val_accuracy: 0.5882
# Epoch 63/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8564 - accuracy: 0.6414 - val_loss: 0.9665 - val_accuracy: 0.5784
# Epoch 64/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8531 - accuracy: 0.6467 - val_loss: 0.9588 - val_accuracy: 0.5858
# Epoch 65/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8526 - accuracy: 0.6414 - val_loss: 0.9683 - val_accuracy: 0.5907
# Epoch 66/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8467 - accuracy: 0.6477 - val_loss: 0.9693 - val_accuracy: 0.5784
# Epoch 67/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8536 - accuracy: 0.6446 - val_loss: 0.9609 - val_accuracy: 0.5809
# Epoch 68/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8510 - accuracy: 0.6477 - val_loss: 0.9611 - val_accuracy: 0.5907
# Epoch 69/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8397 - accuracy: 0.6509 - val_loss: 0.9680 - val_accuracy: 0.5760
# Epoch 70/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8407 - accuracy: 0.6456 - val_loss: 0.9666 - val_accuracy: 0.5760
# Epoch 71/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8587 - accuracy: 0.6351 - val_loss: 0.9587 - val_accuracy: 0.5931
# Epoch 72/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8511 - accuracy: 0.6467 - val_loss: 0.9613 - val_accuracy: 0.5809
# Epoch 73/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8521 - accuracy: 0.6435 - val_loss: 0.9654 - val_accuracy: 0.5907
# Epoch 74/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8335 - accuracy: 0.6593 - val_loss: 0.9644 - val_accuracy: 0.5858
# Epoch 75/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8541 - accuracy: 0.6572 - val_loss: 0.9678 - val_accuracy: 0.5784
# Epoch 76/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8265 - accuracy: 0.6688 - val_loss: 0.9759 - val_accuracy: 0.5711
# Epoch 77/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8353 - accuracy: 0.6498 - val_loss: 0.9758 - val_accuracy: 0.5809
# Epoch 78/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8378 - accuracy: 0.6540 - val_loss: 0.9772 - val_accuracy: 0.5784
# Epoch 79/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8352 - accuracy: 0.6383 - val_loss: 0.9803 - val_accuracy: 0.5882
# Epoch 80/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8419 - accuracy: 0.6519 - val_loss: 0.9727 - val_accuracy: 0.5858
# Epoch 81/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8278 - accuracy: 0.6540 - val_loss: 0.9795 - val_accuracy: 0.5858
# Epoch 82/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8348 - accuracy: 0.6488 - val_loss: 0.9795 - val_accuracy: 0.5833
# Epoch 83/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8441 - accuracy: 0.6425 - val_loss: 0.9808 - val_accuracy: 0.5809
# Epoch 84/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8308 - accuracy: 0.6435 - val_loss: 0.9971 - val_accuracy: 0.5760
# Epoch 85/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8385 - accuracy: 0.6488 - val_loss: 0.9833 - val_accuracy: 0.5760
# Epoch 86/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8366 - accuracy: 0.6530 - val_loss: 0.9820 - val_accuracy: 0.5760
# Epoch 87/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8231 - accuracy: 0.6709 - val_loss: 0.9859 - val_accuracy: 0.5858
# Epoch 88/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8518 - accuracy: 0.6320 - val_loss: 0.9878 - val_accuracy: 0.5833
# Epoch 89/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8321 - accuracy: 0.6572 - val_loss: 0.9835 - val_accuracy: 0.5784
# Epoch 90/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8392 - accuracy: 0.6593 - val_loss: 0.9889 - val_accuracy: 0.5833
# Epoch 91/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8500 - accuracy: 0.6488 - val_loss: 0.9902 - val_accuracy: 0.5760
# Epoch 92/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8456 - accuracy: 0.6446 - val_loss: 0.9863 - val_accuracy: 0.5686
# Epoch 93/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8280 - accuracy: 0.6614 - val_loss: 0.9988 - val_accuracy: 0.5735
# Epoch 94/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.8451 - accuracy: 0.6477 - val_loss: 0.9908 - val_accuracy: 0.5809
# Epoch 95/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8359 - accuracy: 0.6488 - val_loss: 0.9969 - val_accuracy: 0.5760
# Epoch 96/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8338 - accuracy: 0.6477 - val_loss: 0.9903 - val_accuracy: 0.5686
# Epoch 97/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8179 - accuracy: 0.6593 - val_loss: 0.9978 - val_accuracy: 0.5784
# Epoch 98/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8155 - accuracy: 0.6456 - val_loss: 1.0020 - val_accuracy: 0.5637
# Epoch 99/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8308 - accuracy: 0.6540 - val_loss: 0.9935 - val_accuracy: 0.5711
# Epoch 100/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8244 - accuracy: 0.6540 - val_loss: 1.0047 - val_accuracy: 0.5784

# %%
loss_train = NN_model.history.history['loss']
loss_val = NN_model.history.history['val_loss']
epochs = range(1,100+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
Acc_train = NN_model.history.history['accuracy']
Acc_val = NN_model.history.history['val_accuracy']
epochs = range(1,100+1)
plt.plot(epochs, Acc_train, 'g', label='Training accuracy')
plt.plot(epochs, Acc_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
